# %%
# Import the required libraries and dependencies
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import csv
from pathlib import Path
import numpy as np
import time
# %matplotlib inline

# %%
#Import tha required libraries for datapreparation, analysis and preprocessing
import sklearn
import numpy as np
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
#Import Required modules for Linear Regression
from sklearn.model_selection import train_test_split

# Import Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

#Import different Models -  1. linera_model - LogisticRegression
#Import different Models -  5. svm - LinearSVC

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC 
#from sklearn.preprocessing import GetDummies
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
#Linear Regression Library
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
#Import tha relevant alpha vantage libraries
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
#set key
key = '32UEEELX55R5WBXX'
start_date = '2015-04-01'

# %% [markdown]
# # Read Data from preprocessed file and Preprocess the Data

# %%
csv_path = Path("Resources/stock_analysis_data.csv")
stock_analysis_data = pd.read_csv(csv_path, index_col = 'date')
stock_analysis_data
# Out:
#             value   EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2015-06   28.5798  3.84        0.090909              -0.035714      0.022148
# 2015-06  540.0400  3.84        0.090909              -0.035714      0.022148
# 2015-06  520.5100  3.84        0.090909              -0.035714      0.022148
# 2015-06   39.3470  3.84        0.090909              -0.035714      0.022148
# 2015-06  434.0900  3.84        0.090909              -0.035714      0.022148
# ...           ...   ...             ...                    ...           ...
# 2022-02   59.6512  3.35        0.175325               0.000000      0.037556
# 2022-02  136.2333  3.35        0.175325               0.000000      0.037556
# 2022-02  102.7000  3.35        0.175325               0.000000      0.037556
# 2022-02   68.1660  3.35        0.175325               0.000000      0.037556
# 2022-02  120.1474  3.35        0.175325               0.000000      0.037556
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2015-06          -0.053571            0.059537                 1.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# ...                    ...                 ...                 ...
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  ...  %-close_PM-close  \
# date                                            ...
# 2015-06                 0.0                0.0  ...               0.0
# 2015-06                 0.0                0.0  ...               0.0
# 2015-06                 0.0                0.0  ...               0.0
# 2015-06                 0.0                0.0  ...               0.0
# 2015-06                 0.0                0.0  ...               0.0
# ...                     ...                ...  ...               ...
# 2022-02                 0.0                0.0  ...               0.0
# 2022-02                 0.0                0.0  ...               0.0
# 2022-02                 0.0                0.0  ...               0.0
# 2022-02                 0.0                0.0  ...               0.0
# 2022-02                 0.0                1.0  ...               0.0
#
#          %-close_T-close  %-close_UNH-close  %-close_UTX-close  \
# date
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# ...                  ...                ...                ...
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                1.0
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                0.0
#
#          %-close_V-close  %-close_VZ-close  %-close_WFC-close  \
# date
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# ...                  ...               ...                ...
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
#
#          %-close_WMT-close  %-close_XOM-close  Target
# date
# 2015-06                0.0                0.0     0.0
# 2015-06                0.0                0.0     0.0
# 2015-06                0.0                0.0     0.0
# 2015-06                0.0                0.0     0.0
# 2015-06                0.0                0.0     1.0
# ...                    ...                ...     ...
# 2022-02                0.0                0.0     0.0
# 2022-02                0.0                0.0     0.0
# 2022-02                0.0                0.0     1.0
# 2022-02                0.0                0.0     1.0
# 2022-02                0.0                0.0     0.0
#
# [3989 rows x 58 columns]

# %%
FEATURES = list(stock_analysis_data.iloc[:,:-1])
FEATURES
# Out:
# ['value',
#  'EPS',
#  'treausry_yield',
#  'inflation_expectation',
#  'sp500_return',
#  'unemployment_rate',
#  'consumer_sentiment',
#  '%-close_AAPL-close',
#  '%-close_ABBV-close',
#  '%-close_ABT-close',
#  '%-close_AMGN-close',
#  '%-close_AMZN-close',
#  '%-close_BA-close',
#  '%-close_BAC-close',
#  '%-close_BMY-close',
#  '%-close_BRK.B-close',
#  '%-close_C-close',
#  '%-close_CMCSA-close',
#  '%-close_CSCO-close',
#  '%-close_CVX-close',
#  '%-close_DIS-close',
#  '%-close_DWDP-close',
#  '%-close_FB-close',
#  '%-close_GE-close',
#  '%-close_GILD-close',
#  '%-close_GOOG-close',
#  '%-close_GOOGL-close',
#  '%-close_HD-close',
#  '%-close_HON-close',
#  '%-close_IBM-close',
#  '%-close_INTC-close',
#  '%-close_JNJ-close',
#  '%-close_JPM-close',
#  '%-close_KO-close',
#  '%-close_MA-close',
#  '%-close_MCD-close',
#  '%-close_MDT-close',
#  '%-close_MMM-close',
#  '%-close_MO-close',
#  '%-close_MRK-close',
#  '%-close_MSFT-close',
#  '%-close_NFLX-close',
#  '%-close_NKE-close',
#  '%-close_NVDA-close',
#  '%-close_ORCL-close',
#  '%-close_PEP-close',
#  '%-close_PFE-close',
#  '%-close_PG-close',
#  '%-close_PM-close',
#  '%-close_T-close',
#  '%-close_UNH-close',
#  '%-close_UTX-close',
#  '%-close_V-close',
#  '%-close_VZ-close',
#  '%-close_WFC-close',
#  '%-close_WMT-close',
#  '%-close_XOM-close']

# %%
test_frac = 0.2
X = stock_analysis_data[FEATURES]
y = stock_analysis_data['Target']
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = test_frac)
x_train
# Out:
#             value   EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2015-07   79.0932  3.84       -0.029762               0.037037     -0.061345
# 2021-10  166.6035  2.52        0.290698               0.043478     -0.008035
# 2020-01   98.6824  4.71       -0.071429               0.086957     -0.079166
# 2017-05  162.6543  2.38        0.010989               0.040000      0.006374
# 2021-07  119.6129  2.33       -0.095238               0.119048      0.029760
# ...           ...   ...             ...                    ...           ...
# 2019-02   57.9864  4.87       -0.019685              -0.037037      0.018079
# 2018-11  100.1212  3.42       -0.016667              -0.034483     -0.087936
# 2020-07  107.5600  2.18       -0.176471               0.000000      0.069797
# 2016-06  144.7900  2.95       -0.100000               0.083333      0.036471
# 2016-05   96.7997  2.35        0.031746              -0.142857      0.003497
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2015-07          -0.018868           -0.031217                 0.0
# 2021-10          -0.021277           -0.015110                 0.0
# 2020-01          -0.027778            0.005035                 0.0
# 2017-05           0.000000            0.001031                 0.0
# 2021-07          -0.084746           -0.050292                 0.0
# ...                    ...                 ...                 ...
# 2019-02          -0.050000            0.028509                 0.0
# 2018-11           0.000000           -0.011156                 0.0
# 2020-07          -0.072727           -0.071703                 0.0
# 2016-06           0.020833           -0.012672                 0.0
# 2016-05          -0.058824            0.064045                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  ...  %-close_PG-close  \
# date                                            ...
# 2015-07                 0.0                0.0  ...               0.0
# 2021-10                 0.0                0.0  ...               0.0
# 2020-01                 0.0                0.0  ...               0.0
# 2017-05                 0.0                0.0  ...               0.0
# 2021-07                 0.0                1.0  ...               0.0
# ...                     ...                ...  ...               ...
# 2019-02                 0.0                0.0  ...               0.0
# 2018-11                 0.0                0.0  ...               0.0
# 2020-07                 0.0                0.0  ...               0.0
# 2016-06                 0.0                0.0  ...               0.0
# 2016-05                 0.0                0.0  ...               0.0
#
#          %-close_PM-close  %-close_T-close  %-close_UNH-close  \
# date
# 2015-07               0.0              0.0                0.0
# 2021-10               0.0              0.0                0.0
# 2020-01               0.0              0.0                0.0
# 2017-05               0.0              0.0                1.0
# 2021-07               0.0              0.0                0.0
# ...                   ...              ...                ...
# 2019-02               0.0              0.0                0.0
# 2018-11               0.0              0.0                0.0
# 2020-07               0.0              0.0                0.0
# 2016-06               0.0              0.0                0.0
# 2016-05               0.0              0.0                0.0
#
#          %-close_UTX-close  %-close_V-close  %-close_VZ-close  \
# date
# 2015-07                0.0              0.0               0.0
# 2021-10                0.0              0.0               0.0
# 2020-01                0.0              0.0               0.0
# 2017-05                0.0              0.0               0.0
# 2021-07                0.0              0.0               0.0
# ...                    ...              ...               ...
# 2019-02                1.0              0.0               0.0
# 2018-11                0.0              0.0               0.0
# 2020-07                0.0              0.0               0.0
# 2016-06                0.0              0.0               0.0
# 2016-05                0.0              0.0               0.0
#
#          %-close_WFC-close  %-close_WMT-close  %-close_XOM-close
# date
# 2015-07                0.0                0.0                0.0
# 2021-10                0.0                0.0                0.0
# 2020-01                0.0                0.0                0.0
# 2017-05                0.0                0.0                0.0
# 2021-07                0.0                0.0                0.0
# ...                    ...                ...                ...
# 2019-02                0.0                0.0                0.0
# 2018-11                0.0                0.0                0.0
# 2020-07                0.0                0.0                0.0
# 2016-06                0.0                0.0                0.0
# 2016-05                0.0                0.0                0.0
#
# [3191 rows x 57 columns]

# %%
stock_logistic_regression_model = LogisticRegression(solver = 'liblinear')
stock_linear_regression_model.fit(x_train, y_train)
y_pred = stock_linear_regression_model.predict(x_test)

# %%
acc = accuracy_score (y_test, y_pred, normalize = True)
num_acc = accuracy_score (y_test, y_pred, normalize = False)
prec = precision_score (y_test, y_pred)
recall = recall_score (y_test, y_pred)

display(acc)
display(prec)
display(recall)
# Out:
# 0.5538847117794486
# 0.5692068429237948
# 0.8224719101123595

# %%
stock_random_forest_classifirer_model = RandomForestClassifier()
stock_random_forest_classifirer_model.fit(x_train, y_train)
y_pred = stock_random_forest_classifirer_model.predict(x_test)

# %%
rf_acc = accuracy_score (y_test, y_pred, normalize = True)
rf_num_acc = accuracy_score (y_test, y_pred, normalize = False)
rf_prec = precision_score (y_test, y_pred)
rf_recall = recall_score (y_test, y_pred)

display(rf_acc)
display(rf_prec)
display(rf_recall)
# Out:
# 0.681704260651629
# 0.6758747697974218
# 0.8247191011235955

# %%
import pickle

# %%
filename = 'random_forest_classifier.sav'
pickle.dump(stock_random_forest_classifirer_model, open(filename, 'wb'))

# %%
#loading the saved model
loaded_model = pickle.load(open('random_forest_classifier.sav','rb'))

# %%
y1_pred = loaded_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jj/lgtty8dd29z8knbmnn3_jyk80000gn/T/ipykernel_2734/2051872875.py in <module>
#       1 y1_pred = loaded_model.predict(x_test)
# ----> 2 ytest
#
# NameError: name 'ytest' is not defined

# %%
y_test
# Out:
# date
# 2021-12    1.0
# 2016-06    1.0
# 2021-07    1.0
# 2017-06    0.0
# 2020-01    1.0
#           ...
# 2021-10    0.0
# 2018-01    1.0
# 2021-08    0.0
# 2020-05    0.0
# 2015-09    0.0
# Name: Target, Length: 798, dtype: float64

# %%
rf_acc = accuracy_score (y_test, y_pred, normalize = True)
rf_num_acc = accuracy_score (y_test, y_pred, normalize = False)
rf_prec = precision_score (y_test, y_pred)
rf_recall = recall_score (y_test, y_pred)

display(rf_acc)
display(rf_prec)
display(rf_recall)
# Out:
# 0.681704260651629
# 0.6758747697974218
# 0.8247191011235955

# %%
csv_path = Path("Resources/Classifier_Test.csv")
stock_test = pd.read_csv(csv_path, index_col = 'date', header=1)

# %%
stock_test
# Out:
#             value   EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2022-02  120.1474  3.35        0.175325                    0.0      0.037556
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2022-02              -0.05           -0.065476                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  ...  %-close_PG-close  \
# date                                            ...
# 2022-02                 0.0                1.0  ...               0.0
#
#          %-close_PM-close  %-close_T-close  %-close_UNH-close  \
# date
# 2022-02               0.0              0.0                0.0
#
#          %-close_UTX-close  %-close_V-close  %-close_VZ-close  \
# date
# 2022-02                0.0              0.0               0.0
#
#          %-close_WFC-close  %-close_WMT-close  %-close_XOM-close
# date
# 2022-02                0.0                0.0                0.0
#
# [1 rows x 57 columns]

# %%
prediction = loaded_model.predict(stock_test)

# %%
print(prediction)
# Out:
# [0.]

# %%
if prediction [0] == 0:
    print('Buy the stocks')
else:
    print('Buy the stocks')
# Out:
# Buy the stocks

# %%
csv_path = Path("Resources/stock_analysis_data_lr.csv")
stock_analysis_data_lr = pd.read_csv(csv_path, index_col = 'date')
stock_analysis_data
# Out:
#           EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2015-06  3.84        0.090909              -0.035714      0.022148
# 2015-06  3.84        0.090909              -0.035714      0.022148
# 2015-06  3.84        0.090909              -0.035714      0.022148
# 2015-06  3.84        0.090909              -0.035714      0.022148
# 2015-06  3.84        0.090909              -0.035714      0.022148
# ...       ...             ...                    ...           ...
# 2022-02  3.35        0.175325               0.000000      0.037556
# 2022-02  3.35        0.175325               0.000000      0.037556
# 2022-02  3.35        0.175325               0.000000      0.037556
# 2022-02  3.35        0.175325               0.000000      0.037556
# 2022-02  3.35        0.175325               0.000000      0.037556
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2015-06          -0.053571            0.059537                 1.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# 2015-06          -0.053571            0.059537                 0.0
# ...                    ...                 ...                 ...
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
# 2022-02          -0.050000           -0.065476                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  %-close_AMGN-close  ...  \
# date                                                                ...
# 2015-06                 0.0                0.0                 0.0  ...
# 2015-06                 0.0                0.0                 0.0  ...
# 2015-06                 0.0                0.0                 0.0  ...
# 2015-06                 0.0                0.0                 0.0  ...
# 2015-06                 0.0                0.0                 0.0  ...
# ...                     ...                ...                 ...  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                1.0                 0.0  ...
#
#          %-close_T-close  %-close_UNH-close  %-close_UTX-close  \
# date
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# 2015-06              0.0                0.0                0.0
# ...                  ...                ...                ...
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                1.0
# 2022-02              0.0                0.0                0.0
# 2022-02              0.0                0.0                0.0
#
#          %-close_V-close  %-close_VZ-close  %-close_WFC-close  \
# date
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# 2015-06              0.0               0.0                0.0
# ...                  ...               ...                ...
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
# 2022-02              0.0               0.0                0.0
#
#          %-close_WMT-close  %-close_XOM-close  Target     value
# date
# 2015-06                0.0                0.0     0.0   28.5798
# 2015-06                0.0                0.0     0.0  540.0400
# 2015-06                0.0                0.0     0.0  520.5100
# 2015-06                0.0                0.0     0.0   39.3470
# 2015-06                0.0                0.0     1.0  434.0900
# ...                    ...                ...     ...       ...
# 2022-02                0.0                0.0     0.0   59.6512
# 2022-02                0.0                0.0     0.0  136.2333
# 2022-02                0.0                0.0     1.0  102.7000
# 2022-02                0.0                0.0     1.0   68.1660
# 2022-02                0.0                0.0     0.0  120.1474
#
# [3989 rows x 58 columns]

# %%
FEATURES = list(stock_analysis_data_lr.iloc[:,:-1])
FEATURES
# Out:
# ['EPS',
#  'treausry_yield',
#  'inflation_expectation',
#  'sp500_return',
#  'unemployment_rate',
#  'consumer_sentiment',
#  '%-close_AAPL-close',
#  '%-close_ABBV-close',
#  '%-close_ABT-close',
#  '%-close_AMGN-close',
#  '%-close_AMZN-close',
#  '%-close_BA-close',
#  '%-close_BAC-close',
#  '%-close_BMY-close',
#  '%-close_BRK.B-close',
#  '%-close_C-close',
#  '%-close_CMCSA-close',
#  '%-close_CSCO-close',
#  '%-close_CVX-close',
#  '%-close_DIS-close',
#  '%-close_DWDP-close',
#  '%-close_FB-close',
#  '%-close_GE-close',
#  '%-close_GILD-close',
#  '%-close_GOOG-close',
#  '%-close_GOOGL-close',
#  '%-close_HD-close',
#  '%-close_HON-close',
#  '%-close_IBM-close',
#  '%-close_INTC-close',
#  '%-close_JNJ-close',
#  '%-close_JPM-close',
#  '%-close_KO-close',
#  '%-close_MA-close',
#  '%-close_MCD-close',
#  '%-close_MDT-close',
#  '%-close_MMM-close',
#  '%-close_MO-close',
#  '%-close_MRK-close',
#  '%-close_MSFT-close',
#  '%-close_NFLX-close',
#  '%-close_NKE-close',
#  '%-close_NVDA-close',
#  '%-close_ORCL-close',
#  '%-close_PEP-close',
#  '%-close_PFE-close',
#  '%-close_PG-close',
#  '%-close_PM-close',
#  '%-close_T-close',
#  '%-close_UNH-close',
#  '%-close_UTX-close',
#  '%-close_V-close',
#  '%-close_VZ-close',
#  '%-close_WFC-close',
#  '%-close_WMT-close',
#  '%-close_XOM-close',
#  'Target']

# %%
test_frac = 0.2
Xlr = stock_analysis_data_lr[FEATURES]
ylr = stock_analysis_data_lr['value']
x_train_lr, x_test_lr, y_train_lr, y_test_lr = train_test_split(Xlr,ylr, test_size = test_frac)
x_train_lr
# Out:
#           EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2020-10  2.58        0.259259               0.000000      0.108777
# 2017-07  2.97        0.056497               0.000000      0.002918
# 2021-06  2.33        0.024390              -0.086957      0.024413
# 2017-10  3.30        0.100000              -0.111111      0.030566
# 2019-08  3.17       -0.185792               0.038462      0.019479
# ...       ...             ...                    ...           ...
# 2018-07  3.08        0.000000              -0.033333      0.031920
# 2020-03  1.84       -0.553030              -0.083333      0.126984
# 2016-08  2.95        0.056075              -0.074074      0.000078
# 2018-07  3.08        0.000000              -0.033333      0.031920
# 2019-04  2.25       -0.016878               0.000000     -0.063771
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2020-10          -0.126582            0.017413                 0.0
# 2017-07           0.000000           -0.016842                 0.0
# 2021-06           0.017241            0.031363                 0.0
# 2017-10          -0.023256            0.058885                 0.0
# 2019-08           0.000000           -0.087398                 0.0
# ...                    ...                 ...                 ...
# 2018-07          -0.050000           -0.003055                 0.0
# 2020-03           0.257143           -0.117822                 0.0
# 2016-08           0.020833           -0.002222                 0.0
# 2018-07          -0.050000           -0.003055                 0.0
# 2019-04          -0.052632           -0.012195                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  %-close_AMGN-close  ...  \
# date                                                                ...
# 2020-10                 0.0                0.0                 0.0  ...
# 2017-07                 0.0                0.0                 0.0  ...
# 2021-06                 0.0                0.0                 0.0  ...
# 2017-10                 0.0                0.0                 0.0  ...
# 2019-08                 1.0                0.0                 0.0  ...
# ...                     ...                ...                 ...  ...
# 2018-07                 0.0                0.0                 1.0  ...
# 2020-03                 0.0                0.0                 0.0  ...
# 2016-08                 0.0                0.0                 0.0  ...
# 2018-07                 0.0                0.0                 0.0  ...
# 2019-04                 0.0                0.0                 0.0  ...
#
#          %-close_PM-close  %-close_T-close  %-close_UNH-close  \
# date
# 2020-10               0.0              0.0                0.0
# 2017-07               0.0              1.0                0.0
# 2021-06               0.0              0.0                0.0
# 2017-10               0.0              0.0                0.0
# 2019-08               0.0              0.0                0.0
# ...                   ...              ...                ...
# 2018-07               0.0              0.0                0.0
# 2020-03               0.0              0.0                0.0
# 2016-08               0.0              0.0                0.0
# 2018-07               0.0              0.0                0.0
# 2019-04               0.0              0.0                0.0
#
#          %-close_UTX-close  %-close_V-close  %-close_VZ-close  \
# date
# 2020-10                0.0              0.0               0.0
# 2017-07                0.0              0.0               0.0
# 2021-06                0.0              0.0               0.0
# 2017-10                0.0              0.0               0.0
# 2019-08                0.0              0.0               0.0
# ...                    ...              ...               ...
# 2018-07                0.0              0.0               0.0
# 2020-03                0.0              0.0               0.0
# 2016-08                0.0              0.0               0.0
# 2018-07                0.0              0.0               0.0
# 2019-04                0.0              0.0               1.0
#
#          %-close_WFC-close  %-close_WMT-close  %-close_XOM-close  Target
# date
# 2020-10                0.0                0.0                0.0     0.0
# 2017-07                0.0                0.0                0.0     1.0
# 2021-06                0.0                0.0                0.0     1.0
# 2017-10                0.0                0.0                0.0     0.0
# 2019-08                0.0                0.0                0.0     0.0
# ...                    ...                ...                ...     ...
# 2018-07                0.0                0.0                0.0     1.0
# 2020-03                0.0                0.0                0.0     0.0
# 2016-08                0.0                0.0                0.0     1.0
# 2018-07                0.0                0.0                1.0     0.0
# 2019-04                0.0                0.0                0.0     0.0
#
# [3191 rows x 57 columns]

# %%
stock_random_forest_regression_model = RandomForestRegressor()
stock_random_forest_regression_model.fit(x_train_lr, y_train_lr)
#        1686.0747  ,  174.709221,   52.816508,  146.597318,  124.657661,
#          81.700748,   27.411725,   21.837497,   40.420219,  172.933274,
#          84.545949,  227.489892,   41.559449,  192.468588,   20.750209,
#         131.16926 ,  105.138469,  173.317829,   39.72459 ,   68.153093,
#          50.28007 ,  182.045866,   80.668754,   91.910244,   48.256617,
#         189.7255  ,  202.338948,   74.805803,  107.869967,  812.1825  ,
#         214.9189  ,  207.108719,   84.256762,  110.49463 ,  106.678227,
#          31.144045,  116.416574,  100.6114  ,  283.458443,   27.951737,
#         159.824437,  107.613433,  211.1544  ,   59.835257,  162.132753,
#          39.296003,  139.022693,   82.095778,   19.561039,   81.285514,
#          41.342168,  207.5809  ,   42.152913, 1080.7822  ,   31.523402,
#         166.710882,   36.955419,  165.145975,   67.728101,   54.176547,
#         126.576841,  154.706443,   65.600466,  110.998844,  110.28881 ,
#         113.135789,  126.229179,   72.819858,   46.319712,   45.558301,
#          49.632639,   51.340799,   48.747853,   22.285896,  104.197957,
#          95.901004,  223.603352,  195.0441  ,  111.623784,   52.406054,
#          76.271214,  875.9083  ,   36.239095,  109.781668,   46.121049,
#         153.821232,   92.010846,   97.441967,  160.365418,   75.593097,
#          62.517065,   69.277248,   92.945233,  154.654876,  181.289777,
#          39.516905,   52.740399,   65.100588,  209.404971,   92.329603,
#          31.790342,  153.209551,  201.603573,  167.97176 ,   32.204713,
#          51.161179,   83.740435,   55.185925,  124.390219,   49.541381,
#          34.974825,   36.658294,   54.533777,   81.799472,   33.297872,
#         107.414958,   21.342572,   58.520738,   66.775929,  499.7022  ,
#          88.152858,  105.269903,   33.692632])

# %%
# RandomForestClassifier
def linear_regression_fn(xlr_train, ylr_train):
    model_lr = LinearRegression()
    model_lr.fit(xlr_train, ylr_train)
    return model_lr

# %%
stock_linear_regression_model = LinearRegression()
stock_linear_regression_model.fit(x_train_lr, y_train_lr)
ylr_pred = stock_linear_regression_model.predict(x_test_lr)
ylr_pred
# Out:
# array([ 1.16215460e+02,  2.88811373e+00,  1.83977865e+02,  2.91620707e+01,
#         2.24297846e+01,  3.38650026e+01,  2.10881094e+02,  1.87704861e+02,
#         1.74771473e+03,  1.38090451e+02,  2.23827071e+02,  2.33202751e+02,
#         4.24826207e+01,  4.18958110e+01,  1.15959186e+02,  1.16427532e+02,
#         6.72237854e+01,  1.87408537e+01,  2.03987280e+02,  9.72345309e+01,
#         2.51824305e+02,  1.60148666e+02,  1.50501460e+02,  6.30769269e+01,
#         1.51712506e+01,  2.48489465e+02,  5.85466140e+00,  1.11734264e+01,
#         3.44269171e+01,  7.45872305e+01,  7.35991325e+01,  7.45366481e+01,
#         7.98245511e+01,  8.90512071e+01,  2.52862091e+02,  1.03449371e+02,
#         7.73829270e+00,  2.13468124e+02,  2.00283878e+02,  1.04275821e+02,
#         1.00635073e+02,  7.89282883e+01,  5.99459327e+01,  7.97231283e+01,
#        -2.76265179e+01,  1.27268888e+03,  1.27857564e+03,  1.42759989e+02,
#         1.84227190e+02,  1.74652886e+03,  1.59121214e+02,  1.58900749e+02,
#         1.95947553e+01,  1.33039658e+01,  1.82449716e+01,  6.78806620e+01,
#         1.31090747e+01,  7.22761243e+01,  1.19567996e+02,  2.17791656e+01,
#         4.82243890e+01,  1.18813415e+02,  3.07487620e+02,  1.06362032e+02,
#         8.89879953e+01,  3.72734638e+01])

# %%
r21_score = r2_score(y_test_lr, ylr_pred, multioutput='variance_weighted')
print(r21_score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jj/lgtty8dd29z8knbmnn3_jyk80000gn/T/ipykernel_2734/1998382623.py in <module>
# ----> 1 r21_score = r2_score(y_test_lr, ylr_pred, multioutput='variance_weighted')
#       2 print(r21_score)
#
# TypeError: 'numpy.float64' object is not callable

# %%
filename = 'random_forest_regressor.sav'
pickle.dump(stock_random_forest_regression_model, open(filename, 'wb'))

# %%
#loading the saved model
loaded_model_lr = pickle.load(open('random_forest_regressor.sav','rb'))

# %% [markdown]
# value
# 59.6512
# 136.2333
# 102.7
# 68.166
# 120.1474

# %%
csv_path = Path("Resources/stock_test_regression.csv")
stock_test_regr = pd.read_csv(csv_path, index_col = 'date', header=1)
stock_test_regr
# Out:
#           EPS  treausry_yield  inflation_expectation  sp500_return  \
# date
# 2022-02  3.35        0.175325                    0.0      0.037556
# 2022-02  3.35        0.175325                    0.0      0.037556
# 2022-02  3.35        0.175325                    0.0      0.037556
# 2022-02  3.35        0.175325                    0.0      0.037556
# 2022-02  3.35        0.175325                    0.0      0.037556
#
#          unemployment_rate  consumer_sentiment  %-close_AAPL-close  \
# date
# 2022-02              -0.05           -0.065476                 0.0
# 2022-02              -0.05           -0.065476                 0.0
# 2022-02              -0.05           -0.065476                 0.0
# 2022-02              -0.05           -0.065476                 0.0
# 2022-02              -0.05           -0.065476                 0.0
#
#          %-close_ABBV-close  %-close_ABT-close  %-close_AMGN-close  ...  \
# date                                                                ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                0.0                 0.0  ...
# 2022-02                 0.0                1.0                 0.0  ...
#
#          %-close_PM-close  %-close_T-close  %-close_UNH-close  \
# date
# 2022-02               0.0              0.0                0.0
# 2022-02               0.0              0.0                0.0
# 2022-02               0.0              0.0                0.0
# 2022-02               0.0              0.0                0.0
# 2022-02               0.0              0.0                0.0
#
#          %-close_UTX-close  %-close_V-close  %-close_VZ-close  \
# date
# 2022-02                0.0              0.0               0.0
# 2022-02                0.0              0.0               0.0
# 2022-02                1.0              0.0               0.0
# 2022-02                0.0              0.0               0.0
# 2022-02                0.0              0.0               0.0
#
#          %-close_WFC-close  %-close_WMT-close  %-close_XOM-close  Target
# date
# 2022-02                0.0                0.0                0.0     0.0
# 2022-02                0.0                0.0                0.0     0.0
# 2022-02                0.0                0.0                0.0     1.0
# 2022-02                0.0                0.0                0.0     1.0
# 2022-02                0.0                0.0                0.0     0.0
#
# [5 rows x 57 columns]

# %%
regr_predictions = loaded_model_lr.predict(stock_test_regr)
regr_predictions
# Out:
# array([ 59.9283  , 126.619401,  64.600623,  64.587928, 112.40737 ])
